# %%
import requests

url = "https://api-football-v1.p.rapidapi.com/v3/fixtures"

querystring = {"date":"2021-01-29"}

headers = {
	"X-RapidAPI-Key": "630322333bmsh894634ec4d1b679p17d2b3jsnf658c1fd7f38",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"get":"fixtures","parameters":{"date":"2021-01-29"},"errors":[],"results":115,"paging":{"current":1,"total":1},"response":[{"fixture":{"id":663684,"referee":"A. S\u00e1nchez","timezone":"UTC","date":"2021-01-29T00:00:00+00:00","timestamp":1611878400,"periods":{"first":1611878400,"second":1611882000},"venue":{"id":1207,"name":"Estadio Rommel Fern\u00e1ndez Guti\u00e9rrez","city":"Ciudad de Panam\u00e1"},"status":{"long":"Match Finished","short":"FT","elapsed":90}},"league":{"id":10,"name":"Friendlies","country":"World","logo":"https:\/\/media-2.api-sports.io\/football\/leagues\/10.png","flag":null,"season":2021,"round":"Friendlies 1"},"teams":{"home":{"id":11,"name":"Panama","logo":"https:\/\/media-1.api-sports.io\/football\/teams\/11.png","winner":null},"away":{"id":14,"name":"Serbia","logo":"https:\/\/media-1.api-sports.io\/football\/teams\/14.png","winner":null}},"goals":{"home":0,"away":0},"score":{"halftime":{"home":0,"away":0},"fulltime":{"home":0,"away":0},"extratime":{"home":null,"away":null},"penalty":{"home":null,"away":null}}},{"fixture":{"id":714615,"referee":null,"timezone":"UTC","date":"2021-01-29T00:00:00+00:00","timestamp":1611878400,"periods":{"first":1611878400,"second":1611882000},"venue":{"id":null,"name":null,"city":null},"status":{"long":"Match Finished","short":"FT","elapsed":90}},"league":{"id":846,"name":"Somali Premier League","country":"Somalia","logo":"https:\/\/media-2.api-sports.io\/football\/leagues\/846.png","flag":"https:\/\/media-3.api-sports.io\/flags\/so.svg","season":2021,"round":"Regular Season - 2"},"teams":{"home":{"id":16808,"name":"Elman","logo":"https:\/\/media-2.api-sports.io\/football\/teams\/16808.png","winner":true},"away":{"id":6417,"name":"Dekedaha","logo":"https:\/\/media-1.api-sports.io\/football\/teams\/6417.png","winner":false}},"goals":{"home":2,"away":1},"score":{"halftime":{"home":null,"away":null},"fulltime":{"home":2,"away":1},"extratime":{"home":null,"away":null},"penalty":{"home":null,"away":null}}},{"fixture":{"id":658875,"referee":"L. Rey Hilfer","timezone":"UTC","date":"2021-01-29T00:10:00+00:00","timestamp":1611879000,"periods":{"first":1611879000,"second":1611882600},"venue":{"id":71,"name":"Estadio Ciudad de Caseros","city":"Caseros, Provincia de Buenos Aires"},"status":{"long":"Match Finished","short":"FT","elapsed":90}},"league":{"id":130,"name":"Copa Argentina","country":"Argentina","logo":"https:\/\/media-2.api-sports.io\/football\/leagues\/130.png","flag":"https:\/\/media-1.api-sports.io\/flags\/ar.svg","season":2020,"round":"1st Round"},"teams":{"home":{"id":459,"name":"Arsenal Sarandi","logo":"https:\/\/media-3.api-sports.io\/football\/teams\/459.png","winner":false},"away":{"id":2428,"name":"Huracan Las Heras","logo":"https:\/\/media-2.api-sports.io\/football\/teams\/2428.png","winner":true}},"goals":{"home":0,"away":1},"score":{"halftime":{"home":0,"away":0},"fulltime":{"home":0,"away":1},"extratime":{"home":null,"away":null},"penalty":{"home":null,"away":null}}},{"fixture":{"id":653560,"referee":"I. Lopez","timezone":"UTC","date":"2021-01-29T01:00:00+00:00","timestamp":1611882000,"periods":{"first":1611882000,"second":1611885600},"venue":{"id":1071,"name":"Estadio Jalisco","city":"Guadalajara"},"status":{"long":"Match Finished","short":"FT","elapsed":90}},"league":{"id":263,"name":"Liga de Expansi\u00f3n MX","country":"Mexico","logo":"https:\/\/media-2.api-sports.io\/football\/leagues\/263.png","flag":"https:\/\/media-1.api-sports.io\/flags\/mx.svg","season":2020,"round":"Clausura - 3"},"teams":{"home":{"id":2307,"name":"Leones Negros UDG","logo":"https:\/\/media-2.api-sports.io\/football\/teams\/2307.png","winner":false},"away":{"id":2297,"name":"Dorados","logo":"https:\/\/media-2.api-sports.io\/football\/teams\/2297.png","winner":true}},"goals":{"home":0,"away":1},"score":{"halftime":{"home":0,"away":1},"fulltime":{"home":0,"away":1},"extratime":{"home":null,"away":null},"penalty":{"home":null,"away":null}}},{"fixture":{"id":652833,"referee":"F. Hern ...

# %%
import json
print(json.dumps(json.loads(response.text),indent=4))
# Out:
# {
#     "get": "fixtures",
#     "parameters": {
#         "date": "2021-01-29"
#     },
#     "errors": [],
#     "results": 115,
#     "paging": {
#         "current": 1,
#         "total": 1
#     },
#     "response": [
#         {
#             "fixture": {
#                 "id": 663684,
#                 "referee": "A. S\u00e1nchez",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T00:00:00+00:00",
#                 "timestamp": 1611878400,
#                 "periods": {
#                     "first": 1611878400,
#                     "second": 1611882000
#                 },
#                 "venue": {
#                     "id": 1207,
#                     "name": "Estadio Rommel Fern\u00e1ndez Guti\u00e9rrez",
#                     "city": "Ciudad de Panam\u00e1"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 10,
#                 "name": "Friendlies",
#                 "country": "World",
#                 "logo": "https://media-2.api-sports.io/football/leagues/10.png",
#                 "flag": null,
#                 "season": 2021,
#                 "round": "Friendlies 1"
#             },
#             "teams": {
#                 "home": {
#                     "id": 11,
#                     "name": "Panama",
#                     "logo": "https://media-1.api-sports.io/football/teams/11.png",
#                     "winner": null
#                 },
#                 "away": {
#                     "id": 14,
#                     "name": "Serbia",
#                     "logo": "https://media-1.api-sports.io/football/teams/14.png",
#                     "winner": null
#                 }
#             },
#             "goals": {
#                 "home": 0,
#                 "away": 0
#             },
#             "score": {
#                 "halftime": {
#                     "home": 0,
#                     "away": 0
#                 },
#                 "fulltime": {
#                     "home": 0,
#                     "away": 0
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 714615,
#                 "referee": null,
#                 "timezone": "UTC",
#                 "date": "2021-01-29T00:00:00+00:00",
#                 "timestamp": 1611878400,
#                 "periods": {
#                     "first": 1611878400,
#                     "second": 1611882000
#                 },
#                 "venue": {
#                     "id": null,
#                     "name": null,
#                     "city": null
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 846,
#                 "name": "Somali Premier League",
#                 "country": "Somalia",
#                 "logo": "https://media-2.api-sports.io/football/leagues/846.png",
#                 "flag": "https://media-3.api-sports.io/flags/so.svg",
#                 "season": 2021,
#                 "round": "Regular Season - 2"
#             },
#             "teams": {
#                 "home": {
#                     "id": 16808,
#                     "name": "Elman",
#                     "logo": "https://media-2.api-sports.io/football/teams/16808.png",
#                     "winner": true
#                 },
#                 "away": {
#                     "id": 6417,
#                     "name": "Dekedaha",
#                     "logo": "https://media-1.api-sports.io/football/teams/6417.png",
#                     "winner": false
#                 }
#             },
#             "goals": {
#                 "home": 2,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "fulltime": {
#                     "home": 2,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 658875,
#                 "referee": "L. Rey Hilfer",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T00:10:00+00:00",
#                 "timestamp": 1611879000,
#                 "periods": {
#                     "first": 1611879000,
#                     "second": 1611882600
#                 },
#                 "venue": {
#                     "id": 71,
#                     "name": "Estadio Ciudad de Caseros",
#                     "city": "Caseros, Provincia de Buenos Aires"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 130,
#                 "name": "Copa Argentina",
#                 "country": "Argentina",
#                 "logo": "https://media-2.api-sports.io/football/leagues/130.png",
#                 "flag": "https://media-1.api-sports.io/flags/ar.svg",
#                 "season": 2020,
#                 "round": "1st Round"
#             },
#             "teams": {
#                 "home": {
#                     "id": 459,
#                     "name": "Arsenal Sarandi",
#                     "logo": "https://media-3.api-sports.io/football/teams/459.png",
#                     "winner": false
#                 },
#                 "away": {
#                     "id": 2428,
#                     "name": "Huracan Las Heras",
#                     "logo": "https://media-2.api-sports.io/football/teams/2428.png",
#                     "winner": true
#                 }
#             },
#             "goals": {
#                 "home": 0,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": 0,
#                     "away": 0
#                 },
#                 "fulltime": {
#                     "home": 0,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 653560,
#                 "referee": "I. Lopez",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T01:00:00+00:00",
#                 "timestamp": 1611882000,
#                 "periods": {
#                     "first": 1611882000,
#                     "second": 1611885600
#                 },
#                 "venue": {
#                     "id": 1071,
#                     "name": "Estadio Jalisco",
#                     "city": "Guadalajara"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 263,
#                 "name": "Liga de Expansi\u00f3n MX",
#                 "country": "Mexico",
#                 "logo": "https://media-2.api-sports.io/football/leagues/263.png",
#                 "flag": "https://media-1.api-sports.io/flags/mx.svg",
#                 "season": 2020,
#                 "round": "Clausura - 3"
#             },
#             "teams": {
#                 "home": {
#                     "id": 2307,
#                     "name": "Leones Negros UDG",
#                     "logo": "https://media-2.api-sports.io/football/teams/2307.png",
#                     "winner": false
#                 },
#                 "away": {
#                     "id": 2297,
#                     "name": "Dorados",
#                     "logo": "https://media-2.api-sports.io/football/teams/2297.png",
#                     "winner": true
#                 }
#             },
#             "goals": {
#                 "home": 0,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": 0,
#                     "away": 1
#                 },
#                 "fulltime": {
#                     "home": 0,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 652833,
#                 "referee": "F. Hern\u00e1ndez",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T03:00:00+00:00",
#                 "timestamp": 1611889200,
#                 "periods": {
#                     "first": 1611889200,
#                     "second": 1611892800
#                 },
#                 "venue": {
#                     "id": 1087,
#                     "name": "Estadio Universitario de Nuevo Le\u00f3n",
#                     "city": "San Nicol\u00e1s de los Garza"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 262,
#                 "name": "Liga MX",
#                 "country": "Mexico",
#                 "logo": "https://media-2.api-sports.io/football/leagues/262.png",
#                 "flag": "https://media-1.api-sports.io/flags/mx.svg",
#                 "season": 2020,
#                 "round": "Clausura - 4"
#             },
#             "teams": {
#                 "home": {
#                     "id": 2279,
#                     "name": "Tigres UANL",
#                     "logo": "https://media-1.api-sports.io/football/teams/2279.png",
#                     "winner": null
#                 },
#                 "away": {
#                     "id": 2288,
#                     "name": "Necaxa",
#                     "logo": "https://media-1.api-sports.io/football/teams/2288.png",
#                     "winner": null
#                 }
#             },
#             "goals": {
#                 "home": 1,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": 1,
#                     "away": 1
#                 },
#                 "fulltime": {
#                     "home": 1,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 651338,
#                 "referee": null,
#                 "timezone": "UTC",
#                 "date": "2021-01-29T07:00:00+00:00",
#                 "timestamp": 1611903600,
#                 "periods": {
#                     "first": 1611903600,
#                     "second": 1611907200
#                 },
#                 "venue": {
#                     "id": 3152,
#                     "name": "Jimma Stadium",
#                     "city": "Jimma"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 363,
#                 "name": "Premier League",
#                 "country": "Ethiopia",
#                 "logo": "https://media-2.api-sports.io/football/leagues/363.png",
#                 "flag": "https://media-3.api-sports.io/flags/et.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 10"
#             },
#             "teams": {
#                 "home": {
#                     "id": 4115,
#                     "name": "Dire Dawa Kenema",
#                     "logo": "https://media-1.api-sports.io/football/teams/4115.png",
#                     "winner": false
#                 },
#                 "away": {
#                     "id": 9987,
#                     "name": "Wolkite Ketema",
#                     "logo": "https://media-3.api-sports.io/football/teams/9987.png",
#                     "winner": true
#                 }
#             },
#             "goals": {
#                 "home": 1,
#                 "away": 3
#             },
#             "score": {
#                 "halftime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "fulltime": {
#                     "home": 1,
#                     "away": 3
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 648442,
#                 "referee": "B. Abraham",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T08:05:00+00:00",
#                 "timestamp": 1611907500,
#                 "periods": {
#                     "first": 1611907500,
#                     "second": 1611911100
#                 },
#                 "venue": {
#                     "id": 131,
#                     "name": "Bankwest Stadium",
#                     "city": "Sydney"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 188,
#                 "name": "A-League",
#                 "country": "Australia",
#                 "logo": "https://media-2.api-sports.io/football/leagues/188.png",
#                 "flag": "https://media-1.api-sports.io/flags/au.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 6"
#             },
#             "teams": {
#                 "home": {
#                     "id": 939,
#                     "name": "Western Sydney Wanderers",
#                     "logo": "https://media-2.api-sports.io/football/teams/939.png",
#                     "winner": null
#                 },
#                 "away": {
#                     "id": 946,
#                     "name": "Newcastle Jets",
#                     "logo": "https://media-2.api-sports.io/football/teams/946.png",
#                     "winner": null
#                 }
#             },
#             "goals": {
#                 "home": 1,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": 1,
#                     "away": 0
#                 },
#                 "fulltime": {
#                     "home": 1,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 649360,
#                 "referee": "R. Durcau",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T08:05:00+00:00",
#                 "timestamp": 1611907500,
#                 "periods": {
#                     "first": 1611907500,
#                     "second": 1611911100
#                 },
#                 "venue": {
#                     "id": 2558,
#                     "name": "Marden Sports Complex",
#                     "city": "Adelaide"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 190,
#                 "name": "W-League",
#                 "country": "Australia",
#                 "logo": "https://media-2.api-sports.io/football/leagues/190.png",
#                 "flag": "https://media-1.api-sports.io/flags/au.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 3"
#             },
#             "teams": {
#                 "home": {
#                     "id": 1972,
#                     "name": "Adelaide United W",
#                     "logo": "https://media-1.api-sports.io/football/teams/1972.png",
#                     "winner": false
#                 },
#                 "away": {
#                     "id": 1976,
#                     "name": "Melbourne Victory W",
#                     "logo": "https://media-2.api-sports.io/football/teams/1976.png",
#                     "winner": true
#                 }
#             },
#             "goals": {
#                 "home": 0,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": 0,
#                     "away": 0
#                 },
#                 "fulltime": {
#                     "home": 0,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 627347,
#                 "referee": null,
#                 "timezone": "UTC",
#                 "date": "2021-01-29T08:30:00+00:00",
#                 "timestamp": 1611909000,
#                 "periods": {
#                     "first": null,
#                     "second": null
#                 },
#                 "venue": {
#                     "id": 842,
#                     "name": "Stadion Pakansari Bogor",
#                     "city": "Cibinong"
#                 },
#                 "status": {
#                     "long": "Match Cancelled",
#                     "short": "CANC",
#                     "elapsed": null
#                 }
#             },
#             "league": {
#                 "id": 274,
#                 "name": "Liga 1",
#                 "country": "Indonesia",
#                 "logo": "https://media-3.api-sports.io/football/leagues/274.png",
#                 "flag": "https://media-1.api-sports.io/flags/id.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 28"
#             },
#             "teams": {
#                 "home": {
#                     "id": 2449,
#                     "name": "PS TIRA",
#                     "logo": "https://media-3.api-sports.io/football/teams/2449.png",
#                     "winner": null
#                 },
#                 "away": {
#                     "id": 2442,
#                     "name": "Pusamania Borneo",
#                     "logo": "https://media-3.api-sports.io/football/teams/2442.png",
#                     "winner": null
#                 }
#             },
#             "goals": {
#                 "home": null,
#                 "away": null
#             },
#             "score": {
#                 "halftime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "fulltime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 651251,
#                 "referee": "K. Ramdasan",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T08:30:00+00:00",
#                 "timestamp": 1611909000,
#                 "periods": {
#                     "first": 1611909000,
#                     "second": 1611912600
#                 },
#                 "venue": {
#                     "id": null,
#                     "name": "Yuba Bharati Krirangan",
#                     "city": "Kolkata, West Bengal"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 324,
#                 "name": "I-League",
#                 "country": "India",
#                 "logo": "https://media-2.api-sports.io/football/leagues/324.png",
#                 "flag": "https://media-1.api-sports.io/flags/in.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 5"
#             },
#             "teams": {
#                 "home": {
#                     "id": 3466,
#                     "name": "Minerva Punjab",
#                     "logo": "https://media-1.api-sports.io/football/teams/3466.png",
#                     "winner": null
#                 },
#                 "away": {
#                     "id": 15586,
#                     "name": "Sudeva",
#                     "logo": "https://media-3.api-sports.io/football/teams/15586.png",
#                     "winner": null
#                 }
#             },
#             "goals": {
#                 "home": 0,
#                 "away": 0
#             },
#             "score": {
#                 "halftime": {
#                     "home": 0,
#                     "away": 0
#                 },
#                 "fulltime": {
#                     "home": 0,
#                     "away": 0
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 738510,
#                 "referee": null,
#                 "timezone": "UTC",
#                 "date": "2021-01-29T10:00:00+00:00",
#                 "timestamp": 1611914400,
#                 "periods": {
#                     "first": 1611914400,
#                     "second": 1611918000
#                 },
#                 "venue": {
#                     "id": null,
#                     "name": null,
#                     "city": null
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 667,
#                 "name": "Friendlies Clubs",
#                 "country": "World",
#                 "logo": "https://media-1.api-sports.io/football/leagues/667.png",
#                 "flag": null,
#                 "season": 2021,
#                 "round": "Club Friendlies 4"
#             },
#             "teams": {
#                 "home": {
#                     "id": 2580,
#                     "name": "Concordia",
#                     "logo": "https://media-1.api-sports.io/football/teams/2580.png",
#                     "winner": null
#                 },
#                 "away": {
#                     "id": 6908,
#                     "name": "Tunari",
#                     "logo": "https://media-1.api-sports.io/football/teams/6908.png",
#                     "winner": null
#                 }
#             },
#             "goals": {
#                 "home": 1,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "fulltime": {
#                     "home": 1,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 651252,
#                 "referee": "J. Singh",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T10:30:00+00:00",
#                 "timestamp": 1611916200,
#                 "periods": {
#                     "first": 1611916200,
#                     "second": 1611919800
#                 },
#                 "venue": {
#                     "id": 2271,
#                     "name": "Kalyani Stadium",
#                     "city": "Kalyani"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 324,
#                 "name": "I-League",
#                 "country": "India",
#                 "logo": "https://media-2.api-sports.io/football/leagues/324.png",
#                 "flag": "https://media-1.api-sports.io/flags/in.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 5"
#             },
#             "teams": {
#                 "home": {
#                     "id": 3461,
#                     "name": "Chennai City",
#                     "logo": "https://media-1.api-sports.io/football/teams/3461.png",
#                     "winner": true
#                 },
#                 "away": {
#                     "id": 3465,
#                     "name": "Indian Arrows",
#                     "logo": "https://media-1.api-sports.io/football/teams/3465.png",
#                     "winner": false
#                 }
#             },
#             "goals": {
#                 "home": 1,
#                 "away": 0
#             },
#             "score": {
#                 "halftime": {
#                     "home": 0,
#                     "away": 0
#                 },
#                 "fulltime": {
#                     "home": 1,
#                     "away": 0
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 654410,
#                 "referee": null,
#                 "timezone": "UTC",
#                 "date": "2021-01-29T11:00:00+00:00",
#                 "timestamp": 1611918000,
#                 "periods": {
#                     "first": 1611918000,
#                     "second": 1611921600
#                 },
#                 "venue": {
#                     "id": 11040,
#                     "name": "Campo N 2 - Complexo Desportivo Odivelas",
#                     "city": "Odivelas"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 701,
#                 "name": "Liga Revela\u00e7\u00e3o U23",
#                 "country": "Portugal",
#                 "logo": "https://media-3.api-sports.io/football/leagues/701.png",
#                 "flag": "https://media-1.api-sports.io/flags/pt.svg",
#                 "season": 2020,
#                 "round": "Championship Round - 4"
#             },
#             "teams": {
#                 "home": {
#                     "id": 15459,
#                     "name": "Belenenses U23",
#                     "logo": "https://media-2.api-sports.io/football/teams/15459.png",
#                     "winner": null
#                 },
#                 "away": {
#                     "id": 15465,
#                     "name": "Leix\u00f5es U23",
#                     "logo": "https://media-1.api-sports.io/football/teams/15465.png",
#                     "winner": null
#                 }
#             },
#             "goals": {
#                 "home": 1,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "fulltime": {
#                     "home": 1,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 654411,
#                 "referee": null,
#                 "timezone": "UTC",
#                 "date": "2021-01-29T11:00:00+00:00",
#                 "timestamp": 1611918000,
#                 "periods": {
#                     "first": 1611918000,
#                     "second": 1611921600
#                 },
#                 "venue": {
#                     "id": 3608,
#                     "name": "Est\u00e1dio Municipal de Machico",
#                     "city": "Madeira"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 701,
#                 "name": "Liga Revela\u00e7\u00e3o U23",
#                 "country": "Portugal",
#                 "logo": "https://media-3.api-sports.io/football/leagues/701.png",
#                 "flag": "https://media-1.api-sports.io/flags/pt.svg",
#                 "season": 2020,
#                 "round": "Championship Round - 4"
#             },
#             "teams": {
#                 "home": {
#                     "id": 15466,
#                     "name": "Mar\u00edtimo U23",
#                     "logo": "https://media-3.api-sports.io/football/teams/15466.png",
#                     "winner": false
#                 },
#                 "away": {
#                     "id": 15469,
#                     "name": "Sporting Braga U23",
#                     "logo": "https://media-1.api-sports.io/football/teams/15469.png",
#                     "winner": true
#                 }
#             },
#             "goals": {
#                 "home": 1,
#                 "away": 3
#             },
#             "score": {
#                 "halftime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "fulltime": {
#                     "home": 1,
#                     "away": 3
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 627348,
#                 "referee": null,
#                 "timezone": "UTC",
#                 "date": "2021-01-29T11:15:00+00:00",
#                 "timestamp": 1611918900,
#                 "periods": {
#                     "first": null,
#                     "second": null
#                 },
#                 "venue": {
#                     "id": null,
#                     "name": "Stadion Andi Mattalatta",
#                     "city": "Makassar"
#                 },
#                 "status": {
#                     "long": "Match Cancelled",
#                     "short": "CANC",
#                     "elapsed": null
#                 }
#             },
#             "league": {
#                 "id": 274,
#                 "name": "Liga 1",
#                 "country": "Indonesia",
#                 "logo": "https://media-3.api-sports.io/football/leagues/274.png",
#                 "flag": "https://media-1.api-sports.io/flags/id.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 28"
#             },
#             "teams": {
#                 "home": {
#                     "id": 2441,
#                     "name": "PSM Makassar",
#                     "logo": "https://media-2.api-sports.io/football/teams/2441.png",
#                     "winner": null
#                 },
#                 "away": {
#                     "id": 2446,
#                     "name": "Persebaya Surabaya",
#                     "logo": "https://media-1.api-sports.io/football/teams/2446.png",
#                     "winner": null
#                 }
#             },
#             "goals": {
#                 "home": null,
#                 "away": null
#             },
#             "score": {
#                 "halftime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "fulltime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 658464,
#                 "referee": "M. Akbarian",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T11:30:00+00:00",
#                 "timestamp": 1611919800,
#                 "periods": {
#                     "first": 1611919800,
#                     "second": 1611923400
#                 },
#                 "venue": {
#                     "id": 853,
#                     "name": "Vatani Stadium",
#                     "city": "Ghaemshahr"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 290,
#                 "name": "Persian Gulf Pro League",
#                 "country": "Iran",
#                 "logo": "https://media-3.api-sports.io/football/leagues/290.png",
#                 "flag": "https://media-3.api-sports.io/flags/ir.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 13"
#             },
#             "teams": {
#                 "home": {
#                     "id": 2719,
#                     "name": "Nassaji Mazandaran",
#                     "logo": "https://media-2.api-sports.io/football/teams/2719.png",
#                     "winner": false
#                 },
#                 "away": {
#                     "id": 2738,
#                     "name": "ZOB Ahan",
#                     "logo": "https://media-1.api-sports.io/football/teams/2738.png",
#                     "winner": true
#                 }
#             },
#             "goals": {
#                 "home": 2,
#                 "away": 3
#             },
#             "score": {
#                 "halftime": {
#                     "home": 1,
#                     "away": 2
#                 },
#                 "fulltime": {
#                     "home": 2,
#                     "away": 3
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 658465,
#                 "referee": "P. Heydari",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T11:30:00+00:00",
#                 "timestamp": 1611919800,
#                 "periods": {
#                     "first": 1611919800,
#                     "second": 1611923400
#                 },
#                 "venue": {
#                     "id": 1704,
#                     "name": "Behnam Mohammadi Stadium",
#                     "city": "Masjed Soleyman"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 290,
#                 "name": "Persian Gulf Pro League",
#                 "country": "Iran",
#                 "logo": "https://media-3.api-sports.io/football/leagues/290.png",
#                 "flag": "https://media-3.api-sports.io/flags/ir.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 13"
#             },
#             "teams": {
#                 "home": {
#                     "id": 2707,
#                     "name": "Naft Masjed Soleyman",
#                     "logo": "https://media-3.api-sports.io/football/teams/2707.png",
#                     "winner": null
#                 },
#                 "away": {
#                     "id": 2733,
#                     "name": "Esteghlal FC",
#                     "logo": "https://media-3.api-sports.io/football/teams/2733.png",
#                     "winner": null
#                 }
#             },
#             "goals": {
#                 "home": 1,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": 1,
#                     "away": 0
#                 },
#                 "fulltime": {
#                     "home": 1,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 658466,
#                 "referee": "K. Nazemi",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T11:30:00+00:00",
#                 "timestamp": 1611919800,
#                 "periods": {
#                     "first": 1611919800,
#                     "second": 1611923400
#                 },
#                 "venue": {
#                     "id": 855,
#                     "name": "Shahid Dastgerdi Stadium",
#                     "city": "Teheran"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 290,
#                 "name": "Persian Gulf Pro League",
#                 "country": "Iran",
#                 "logo": "https://media-3.api-sports.io/football/leagues/290.png",
#                 "flag": "https://media-3.api-sports.io/flags/ir.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 13"
#             },
#             "teams": {
#                 "home": {
#                     "id": 2736,
#                     "name": "Saipa",
#                     "logo": "https://media-2.api-sports.io/football/teams/2736.png",
#                     "winner": false
#                 },
#                 "away": {
#                     "id": 2714,
#                     "name": "Gol Gohar",
#                     "logo": "https://media-3.api-sports.io/football/teams/2714.png",
#                     "winner": true
#                 }
#             },
#             "goals": {
#                 "home": 0,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": 0,
#                     "away": 0
#                 },
#                 "fulltime": {
#                     "home": 0,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 648717,
#                 "referee": null,
#                 "timezone": "UTC",
#                 "date": "2021-01-29T12:00:00+00:00",
#                 "timestamp": 1611921600,
#                 "periods": {
#                     "first": 1611921600,
#                     "second": 1611925200
#                 },
#                 "venue": {
#                     "id": 996,
#                     "name": "Moi International Sports Centre",
#                     "city": "Nairobi"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 276,
#                 "name": "FKF Premier League",
#                 "country": "Kenya",
#                 "logo": "https://media-1.api-sports.io/football/leagues/276.png",
#                 "flag": "https://media-2.api-sports.io/flags/ke.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 8"
#             },
#             "teams": {
#                 "home": {
#                     "id": 2478,
#                     "name": "Wazito FC",
#                     "logo": "https://media-2.api-sports.io/football/teams/2478.png",
#                     "winner": true
#                 },
#                 "away": {
#                     "id": 2462,
#                     "name": "Homeboyz",
#                     "logo": "https://media-2.api-sports.io/football/teams/2462.png",
#                     "winner": false
#                 }
#             },
#             "goals": {
#                 "home": 1,
#                 "away": 0
#             },
#             "score": {
#                 "halftime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "fulltime": {
#                     "home": 1,
#                     "away": 0
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 651339,
#                 "referee": null,
#                 "timezone": "UTC",
#                 "date": "2021-01-29T12:00:00+00:00",
#                 "timestamp": 1611921600,
#                 "periods": {
#                     "first": 1611921600,
#                     "second": 1611925200
#                 },
#                 "venue": {
#                     "id": 3152,
#                     "name": "Jimma Stadium",
#                     "city": "Jimma"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 363,
#                 "name": "Premier League",
#                 "country": "Ethiopia",
#                 "logo": "https://media-2.api-sports.io/football/leagues/363.png",
#                 "flag": "https://media-3.api-sports.io/flags/et.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 10"
#             },
#             "teams": {
#                 "home": {
#                     "id": 4116,
#                     "name": "Ethiopia Bunna",
#                     "logo": "https://media-3.api-sports.io/football/teams/4116.png",
#                     "winner": null
#                 },
#                 "away": {
#                     "id": 4112,
#                     "name": "Bahardar",
#                     "logo": "https://media-2.api-sports.io/football/teams/4112.png",
#                     "winner": null
#                 }
#             },
#             "goals": {
#                 "home": 2,
#                 "away": 2
#             },
#             "score": {
#                 "halftime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "fulltime": {
#                     "home": 2,
#                     "away": 2
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 659309,
#                 "referee": "S. Jackson",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T12:00:00+00:00",
#                 "timestamp": 1611921600,
#                 "periods": {
#                     "first": 1611921600,
#                     "second": 1611925200
#                 },
#                 "venue": {
#                     "id": null,
#                     "name": "Hotspur Way Training Centre",
#                     "city": "London"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 702,
#                 "name": "Premier League 2 Division One",
#                 "country": "England",
#                 "logo": "https://media-3.api-sports.io/football/leagues/702.png",
#                 "flag": "https://media-1.api-sports.io/flags/gb.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 9"
#             },
#             "teams": {
#                 "home": {
#                     "id": 15638,
#                     "name": "Tottenham Hotspur U23",
#                     "logo": "https://media-2.api-sports.io/football/teams/15638.png",
#                     "winner": null
#                 },
#                 "away": {
#                     "id": 15631,
#                     "name": "Arsenal U23",
#                     "logo": "https://media-3.api-sports.io/football/teams/15631.png",
#                     "winner": null
#                 }
#             },
#             "goals": {
#                 "home": 1,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": 1,
#                     "away": 1
#                 },
#                 "fulltime": {
#                     "home": 1,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 640424,
#                 "referee": null,
#                 "timezone": "UTC",
#                 "date": "2021-01-29T12:20:00+00:00",
#                 "timestamp": 1611922800,
#                 "periods": {
#                     "first": 1611922800,
#                     "second": 1611926400
#                 },
#                 "venue": {
#                     "id": 1376,
#                     "name": "Prince Saud bin Jalawi Stadium",
#                     "city": "Khobar"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 308,
#                 "name": "Division 1",
#                 "country": "Saudi-Arabia",
#                 "logo": "https://media-2.api-sports.io/football/leagues/308.png",
#                 "flag": "https://media-1.api-sports.io/flags/sa.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 18"
#             },
#             "teams": {
#                 "home": {
#                     "id": 2984,
#                     "name": "Al-Thuqbah",
#                     "logo": "https://media-1.api-sports.io/football/teams/2984.png",
#                     "winner": false
#                 },
#                 "away": {
#                     "id": 2942,
#                     "name": "Al Taee",
#                     "logo": "https://media-1.api-sports.io/football/teams/2942.png",
#                     "winner": true
#                 }
#             },
#             "goals": {
# ...
#                     "home": null,
#                     "away": null
#                 },
#                 "fulltime": {
#                     "home": 3,
#                     "away": 3
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 658519,
#                 "referee": null,
#                 "timezone": "UTC",
#                 "date": "2021-01-29T22:00:00+00:00",
#                 "timestamp": 1611957600,
#                 "periods": {
#                     "first": 1611957600,
#                     "second": 1611961200
#                 },
#                 "venue": {
#                     "id": null,
#                     "name": "Estadio Nacional de F\u00fatbol",
#                     "city": "Managua"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 565,
#                 "name": "Liga Primera U20",
#                 "country": "Nicaragua",
#                 "logo": "https://media-1.api-sports.io/football/leagues/565.png",
#                 "flag": "https://media-1.api-sports.io/flags/ni.svg",
#                 "season": 2021,
#                 "round": "Clausura - 3"
#             },
#             "teams": {
#                 "home": {
#                     "id": 14033,
#                     "name": "CD Junior Managua U20",
#                     "logo": "https://media-2.api-sports.io/football/teams/14033.png",
#                     "winner": true
#                 },
#                 "away": {
#                     "id": 12166,
#                     "name": "Deportivo Ocotal U20",
#                     "logo": "https://media-1.api-sports.io/football/teams/12166.png",
#                     "winner": false
#                 }
#             },
#             "goals": {
#                 "home": 5,
#                 "away": 3
#             },
#             "score": {
#                 "halftime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "fulltime": {
#                     "home": 5,
#                     "away": 3
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 658520,
#                 "referee": null,
#                 "timezone": "UTC",
#                 "date": "2021-01-29T22:00:00+00:00",
#                 "timestamp": 1611957600,
#                 "periods": {
#                     "first": 1611957600,
#                     "second": 1611961200
#                 },
#                 "venue": {
#                     "id": 3500,
#                     "name": "Complejo Deportivo De F\u00fatbol Arnoldo y Matty Ch\u00e1vez",
#                     "city": "Masaya"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 565,
#                 "name": "Liga Primera U20",
#                 "country": "Nicaragua",
#                 "logo": "https://media-1.api-sports.io/football/leagues/565.png",
#                 "flag": "https://media-1.api-sports.io/flags/ni.svg",
#                 "season": 2021,
#                 "round": "Clausura - 3"
#             },
#             "teams": {
#                 "home": {
#                     "id": 12168,
#                     "name": "Juventus Managua U20",
#                     "logo": "https://media-1.api-sports.io/football/teams/12168.png",
#                     "winner": null
#                 },
#                 "away": {
#                     "id": 12167,
#                     "name": "Diriang\u00e9n U20",
#                     "logo": "https://media-1.api-sports.io/football/teams/12167.png",
#                     "winner": null
#                 }
#             },
#             "goals": {
#                 "home": 1,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "fulltime": {
#                     "home": 1,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 324160,
#                 "referee": "N. Vignolo",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T22:15:00+00:00",
#                 "timestamp": 1611958500,
#                 "periods": {
#                     "first": 1611958500,
#                     "second": 1611962100
#                 },
#                 "venue": {
#                     "id": 1624,
#                     "name": "Estadio Centenario",
#                     "city": "Montevideo"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 270,
#                 "name": "Primera Divisi\u00f3n - Clausura",
#                 "country": "Uruguay",
#                 "logo": "https://media-2.api-sports.io/football/leagues/270.png",
#                 "flag": "https://media-2.api-sports.io/flags/uy.svg",
#                 "season": 2020,
#                 "round": "Clausura - 3"
#             },
#             "teams": {
#                 "home": {
#                     "id": 2361,
#                     "name": "Boston River",
#                     "logo": "https://media-3.api-sports.io/football/teams/2361.png",
#                     "winner": true
#                 },
#                 "away": {
#                     "id": 2369,
#                     "name": "Cerro Largo",
#                     "logo": "https://media-3.api-sports.io/football/teams/2369.png",
#                     "winner": false
#                 }
#             },
#             "goals": {
#                 "home": 2,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": 1,
#                     "away": 1
#                 },
#                 "fulltime": {
#                     "home": 2,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 328737,
#                 "referee": "Rodrigo Jos\u00e9 Pereira de Lima",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T22:15:00+00:00",
#                 "timestamp": 1611958500,
#                 "periods": {
#                     "first": 1611958500,
#                     "second": 1611962100
#                 },
#                 "venue": {
#                     "id": 232,
#                     "name": "Est\u00e1dio Rei Pel\u00e9",
#                     "city": "Macei\u00f3, Alagoas"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 72,
#                 "name": "Serie B",
#                 "country": "Brazil",
#                 "logo": "https://media-1.api-sports.io/football/leagues/72.png",
#                 "flag": "https://media-1.api-sports.io/flags/br.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 38"
#             },
#             "teams": {
#                 "home": {
#                     "id": 146,
#                     "name": "CRB",
#                     "logo": "https://media-3.api-sports.io/football/teams/146.png",
#                     "winner": true
#                 },
#                 "away": {
#                     "id": 1193,
#                     "name": "Cuiaba",
#                     "logo": "https://media-2.api-sports.io/football/teams/1193.png",
#                     "winner": false
#                 }
#             },
#             "goals": {
#                 "home": 4,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": 2,
#                     "away": 0
#                 },
#                 "fulltime": {
#                     "home": 4,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 328739,
#                 "referee": "Thayslane Costa",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T22:15:00+00:00",
#                 "timestamp": 1611958500,
#                 "periods": {
#                     "first": 1611958500,
#                     "second": 1611962100
#                 },
#                 "venue": {
#                     "id": 219,
#                     "name": "Est\u00e1dio Santa Cruz",
#                     "city": "Ribeir\u00e3o Preto, S\u00e3o Paulo"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 72,
#                 "name": "Serie B",
#                 "country": "Brazil",
#                 "logo": "https://media-1.api-sports.io/football/leagues/72.png",
#                 "flag": "https://media-1.api-sports.io/flags/br.svg",
#                 "season": 2020,
#                 "round": "Regular Season - 38"
#             },
#             "teams": {
#                 "home": {
#                     "id": 2618,
#                     "name": "Botafogo SP",
#                     "logo": "https://media-2.api-sports.io/football/teams/2618.png",
#                     "winner": false
#                 },
#                 "away": {
#                     "id": 1223,
#                     "name": "Operario-PR",
#                     "logo": "https://media-3.api-sports.io/football/teams/1223.png",
#                     "winner": true
#                 }
#             },
#             "goals": {
#                 "home": 0,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": 0,
#                     "away": 1
#                 },
#                 "fulltime": {
#                     "home": 0,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 656228,
#                 "referee": "W. Mosquera",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T23:00:00+00:00",
#                 "timestamp": 1611961200,
#                 "periods": {
#                     "first": 1611961200,
#                     "second": 1611964800
#                 },
#                 "venue": {
#                     "id": 1779,
#                     "name": "Estadio de F\u00fatbol Jaraguay de Monter\u00eda",
#                     "city": "Monter\u00eda"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 239,
#                 "name": "Primera A",
#                 "country": "Colombia",
#                 "logo": "https://media-3.api-sports.io/football/leagues/239.png",
#                 "flag": "https://media-1.api-sports.io/flags/co.svg",
#                 "season": 2021,
#                 "round": "Apertura - 3"
#             },
#             "teams": {
#                 "home": {
#                     "id": 1133,
#                     "name": "Jaguares",
#                     "logo": "https://media-2.api-sports.io/football/teams/1133.png",
#                     "winner": true
#                 },
#                 "away": {
#                     "id": 1141,
#                     "name": "Alianza Petrolera",
#                     "logo": "https://media-2.api-sports.io/football/teams/1141.png",
#                     "winner": false
#                 }
#             },
#             "goals": {
#                 "home": 2,
#                 "away": 0
#             },
#             "score": {
#                 "halftime": {
#                     "home": 1,
#                     "away": 0
#                 },
#                 "fulltime": {
#                     "home": 2,
#                     "away": 0
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         },
#         {
#             "fixture": {
#                 "id": 653554,
#                 "referee": "D. Quintero",
#                 "timezone": "UTC",
#                 "date": "2021-01-29T23:30:00+00:00",
#                 "timestamp": 1611963000,
#                 "periods": {
#                     "first": 1611963000,
#                     "second": 1611966600
#                 },
#                 "venue": {
#                     "id": 11624,
#                     "name": "Estadio Ciudad de los Deportes",
#                     "city": "D.F."
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
#                     "elapsed": 90
#                 }
#             },
#             "league": {
#                 "id": 263,
#                 "name": "Liga de Expansi\u00f3n MX",
#                 "country": "Mexico",
#                 "logo": "https://media-2.api-sports.io/football/leagues/263.png",
#                 "flag": "https://media-1.api-sports.io/flags/mx.svg",
#                 "season": 2020,
#                 "round": "Clausura - 3"
#             },
#             "teams": {
#                 "home": {
#                     "id": 2312,
#                     "name": "Atlante FC",
#                     "logo": "https://media-3.api-sports.io/football/teams/2312.png",
#                     "winner": true
#                 },
#                 "away": {
#                     "id": 14280,
#                     "name": "Tlaxcala",
#                     "logo": "https://media-2.api-sports.io/football/teams/14280.png",
#                     "winner": false
#                 }
#             },
#             "goals": {
#                 "home": 2,
#                 "away": 1
#             },
#             "score": {
#                 "halftime": {
#                     "home": 2,
#                     "away": 0
#                 },
#                 "fulltime": {
#                     "home": 2,
#                     "away": 1
#                 },
#                 "extratime": {
#                     "home": null,
#                     "away": null
#                 },
#                 "penalty": {
#                     "home": null,
#                     "away": null
#                 }
#             }
#         }
#     ]
# }
